# %%
import pandas as pd
import numpy as np
import seaborn as cns

# %%
df = pd.read_csv('supershops.csv')
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
df.isnull().sum()
# Out:
# Marketing Spend    0
# Administration     0
# Transport          1
# Area               0
# Profit             0
# dtype: int64

# %%
df.dropna()
# Out:
#     Marketing Spend  Administration  Transport     Area     Profit
# 0         114523.61       136897.80  471784.10    Dhaka  192261.83
# 1         162597.70       151377.59  443898.53      Ctg  191792.06
# 2         153441.51       101145.55  407934.54  Rangpur  191050.39
# 3         144372.41       118671.85  383199.62    Dhaka  182901.99
# 4         142107.34        91391.77  366168.42  Rangpur  166187.94
# 5         131876.90        99814.71  362861.36    Dhaka  156991.12
# 6         134615.46       147198.87  127716.82      Ctg  156122.51
# 7         130298.13       145530.06  323876.68  Rangpur  155752.60
# 8         120542.52       148718.95  311613.29    Dhaka  152211.77
# 9         123334.88       108679.17  304981.62      Ctg  149759.96
# 10        101913.08       110594.11  229160.95  Rangpur  146121.95
# 11        100671.96        91790.61  249744.55      Ctg  144259.40
# 12         93863.75       127320.38  249839.44  Rangpur  141585.52
# ...

# %%
df.shape
# Out:
# (50, 5)

# %%
df.dropna().shape
# Out:
# (49, 5)

# %%
df.dropna(inplace = True)

# %%
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %% [markdown]
# # MinMax Scaler / Normalization

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
m = MinMaxScaler() #creating object for MinMax Scaler

# %%
ms_fit = m.fit(df[['Marketing Spend']]) #fit / train
ms_fit
# Out:
# MinMaxScaler()

# %%
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
df['Marketing Spend'] = m.transform(df[['Marketing Spend']]) #transform the data

# %%
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0         0.692617       136897.80  471784.10    Dhaka  192261.83
# 1         0.983359       151377.59  443898.53      Ctg  191792.06
# 2         0.927985       101145.55  407934.54  Rangpur  191050.39
# 3         0.873136       118671.85  383199.62    Dhaka  182901.99
# 4         0.859438        91391.77  366168.42  Rangpur  166187.94

# %%
#At a time fit & transform
df['Administration'] = m.transform(df[['Administration']])

# %%
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0         0.692617        0.827931  471784.10    Dhaka  192261.83
# 1         0.983359        0.915502  443898.53      Ctg  191792.06
# 2         0.927985        0.611709  407934.54  Rangpur  191050.39
# 3         0.873136        0.717704  383199.62    Dhaka  182901.99
# 4         0.859438        0.552720  366168.42  Rangpur  166187.94

# %%
df['Transport'] = m.transform(df[['Transport']])

# %%
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0         0.692617        0.827931   2.853259    Dhaka  192261.83
# 1         0.983359        0.915502   2.684613      Ctg  191792.06
# 2         0.927985        0.611709   2.467109  Rangpur  191050.39
# 3         0.873136        0.717704   2.317517    Dhaka  182901.99
# 4         0.859438        0.552720   2.214516  Rangpur  166187.94

# %%
df['Profit'] = m.transform(df[['Profit']])

# %%
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area    Profit
# 0         0.692617        0.827931   2.853259    Dhaka  1.162762
# 1         0.983359        0.915502   2.684613      Ctg  1.159921
# 2         0.927985        0.611709   2.467109  Rangpur  1.155436
# 3         0.873136        0.717704   2.317517    Dhaka  1.106156
# 4         0.859438        0.552720   2.214516  Rangpur  1.005073

# %% [markdown]
# # Standardization

# %%
from sklearn.preprocessing import StandardScaler

# %%
s = StandardScaler() #creating object for StandardScaler

# %%
s_fit = s.fit(df[['Marketing Spend']]) #fit / train
s_fit
# Out:
# StandardScaler()

# %%
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area    Profit
# 0         0.692617        1.383068   2.853259    Dhaka  1.162762
# 1         0.983359        1.698768   2.684613      Ctg  1.159921
# 2         0.927985        0.603569   2.467109  Rangpur  1.155436
# 3         0.873136        0.985691   2.317517    Dhaka  1.106156
# 4         0.859438        0.390909   2.214516  Rangpur  1.005073

# %%
df['Marketing Spend'] = s.transform(df[['Marketing Spend']]) #transform the data

# %%
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area    Profit
# 0         0.895248        1.383068   2.853259    Dhaka  1.162762
# 1         1.943398        1.698768   2.684613      Ctg  1.159921
# 2         1.743767        0.603569   2.467109  Rangpur  1.155436
# 3         1.546035        0.985691   2.317517    Dhaka  1.106156
# 4         1.496650        0.390909   2.214516  Rangpur  1.005073

# %%
#At a time fit & transform
df['Administration'] = s.transform(df[['Administration']])

# %%
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area    Profit
# 0         0.895248        3.384377   2.853259    Dhaka  1.162762
# 1         1.943398        4.522499   2.684613      Ctg  1.159921
# 2         1.743767        0.574223   2.467109  Rangpur  1.155436
# 3         1.546035        1.951803   2.317517    Dhaka  1.106156
# 4         1.496650       -0.192431   2.214516  Rangpur  1.005073

# %%
df['Transport'] = s.transform(df[['Transport']])
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area    Profit
# 0         0.895248        3.384377   8.684527    Dhaka  1.162762
# 1         1.943398        4.522499   8.076544      Ctg  1.159921
# 2         1.743767        0.574223   7.292428  Rangpur  1.155436
# 3         1.546035        1.951803   6.753137    Dhaka  1.106156
# 4         1.496650       -0.192431   6.381810  Rangpur  1.005073

# %%
df['Profit'] = s.transform(df[['Profit']])

# %%
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area    Profit
# 0         0.895248        3.384377   8.684527    Dhaka  2.590159
# 1         1.943398        4.522499   8.076544      Ctg  2.579916
# 2         1.743767        0.574223   7.292428  Rangpur  2.563746
# 3         1.546035        1.951803   6.753137    Dhaka  2.386088
# 4         1.496650       -0.192431   6.381810  Rangpur  2.021675

# %% [markdown]
# # Max Abs Scaler

# %%
from sklearn.preprocessing import MaxAbsScaler

# %%
mas = MaxAbsScaler()

# %%
mas_fit= mas.fit(df[['Marketing Spend']]) #fit / train
mas_fit
# Out:
# MaxAbsScaler()

# %%
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area    Profit
# 0         0.895248        3.384377   8.684527    Dhaka  2.590159
# 1         1.943398        4.522499   8.076544      Ctg  2.579916
# 2         1.743767        0.574223   7.292428  Rangpur  2.563746
# 3         1.546035        1.951803   6.753137    Dhaka  2.386088
# 4         1.496650       -0.192431   6.381810  Rangpur  2.021675

# %%
df['Administration'] = mas.transform(df[['Administration']]) #transform the data

# %%
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area    Profit
# 0         0.895248        1.689327   8.684527    Dhaka  2.590159
# 1         1.943398        2.257425   8.076544      Ctg  2.579916
# 2         1.743767        0.286626   7.292428  Rangpur  2.563746
# 3         1.546035        0.974251   6.753137    Dhaka  2.386088
# 4         1.496650       -0.096053   6.381810  Rangpur  2.021675

# %%
#At a time fit & transform
df['Administration'] = mas.transform(df[['Administration']])

# %%
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area    Profit
# 0         0.895248        0.843235   8.684527    Dhaka  2.590159
# 1         1.943398        1.126804   8.076544      Ctg  2.579916
# 2         1.743767        0.143071   7.292428  Rangpur  2.563746
# 3         1.546035        0.486302   6.753137    Dhaka  2.386088
# 4         1.496650       -0.047945   6.381810  Rangpur  2.021675

# %%
df['Transport'] = mas.transform(df[['Transport']])

# %%
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area    Profit
# 0         0.895248        0.843235   4.334920    Dhaka  2.590159
# 1         1.943398        1.126804   4.031442      Ctg  2.579916
# 2         1.743767        0.143071   3.640048  Rangpur  2.563746
# 3         1.546035        0.486302   3.370858    Dhaka  2.386088
# 4         1.496650       -0.047945   3.185508  Rangpur  2.021675

# %%
df['Profit'] = mas.transform(df[['Profit']])
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area    Profit
# 0         0.895248        0.843235   4.334920    Dhaka  1.292889
# 1         1.943398        1.126804   4.031442      Ctg  1.287777
# 2         1.743767        0.143071   3.640048  Rangpur  1.279705
# 3         1.546035        0.486302   3.370858    Dhaka  1.191026
# 4         1.496650       -0.047945   3.185508  Rangpur  1.009128

# %% [markdown]
# # Robust Scaler

# %%
from sklearn.preprocessing import RobustScaler

# %%
rs = RobustScaler() #creating object for MinMax Scaler

# %%
rs_fit = rs.fit(df[['Marketing Spend']]) #fit / train
rs_fit
# Out:
# RobustScaler()

# %%
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area    Profit
# 0         0.895248        0.843235   4.334920    Dhaka  1.292889
# 1         1.943398        1.126804   4.031442      Ctg  1.287777
# 2         1.743767        0.143071   3.640048  Rangpur  1.279705
# 3         1.546035        0.486302   3.370858    Dhaka  1.191026
# 4         1.496650       -0.047945   3.185508  Rangpur  1.009128

# %%
df['Marketing Spend'] = rs.transform(df[['Marketing Spend']]) #transform the data

# %%
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area    Profit
# 0         0.669502        0.843235   4.334920    Dhaka  1.292889
# 1         1.428312        1.126804   4.031442      Ctg  1.287777
# 2         1.283789        0.143071   3.640048  Rangpur  1.279705
# 3         1.140641        0.486302   3.370858    Dhaka  1.191026
# 4         1.104889       -0.047945   3.185508  Rangpur  1.009128

# %%
#At a time fit & transform
df['Administration'] = rs.transform(df[['Administration']])

# %%
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area    Profit
# 0         0.669502        0.631847   4.334920    Dhaka  1.292889
# 1         1.428312        0.837137   4.031442      Ctg  1.287777
# 2         1.283789        0.124962   3.640048  Rangpur  1.279705
# 3         1.140641        0.373445   3.370858    Dhaka  1.191026
# 4         1.104889       -0.013325   3.185508  Rangpur  1.009128

# %%
df['Transport'] = rs.transform(df[['Transport']])

# %%
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area    Profit
# 0         0.669502        0.631847   3.159660    Dhaka  1.292889
# 1         1.428312        0.837137   2.939956      Ctg  1.287777
# 2         1.283789        0.124962   2.656605  Rangpur  1.279705
# 3         1.140641        0.373445   2.461725    Dhaka  1.191026
# 4         1.104889       -0.013325   2.327541  Rangpur  1.009128

# %%
df['Profit'] = rs.transform(df[['Profit']])

# %%
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area    Profit
# 0         0.669502        0.631847   3.159660    Dhaka  0.957375
# 1         1.428312        0.837137   2.939956      Ctg  0.953674
# 2         1.283789        0.124962   2.656605  Rangpur  0.947831
# 3         1.140641        0.373445   2.461725    Dhaka  0.883631
# 4         1.104889       -0.013325   2.327541  Rangpur  0.751946

# %% [markdown]
# # Max

# %%
df = pd.read_csv('supershops.csv')
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
max_val = df['Marketing Spend'].max()

# %%
max_val
# Out:
# 165349.2

# %%
df['Marketing Spend'] = df['Marketing Spend'] / max_val

# %%
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0         0.692617       136897.80  471784.10    Dhaka  192261.83
# 1         0.983359       151377.59  443898.53      Ctg  191792.06
# 2         0.927985       101145.55  407934.54  Rangpur  191050.39
# 3         0.873136       118671.85  383199.62    Dhaka  182901.99
# 4         0.859438        91391.77  366168.42  Rangpur  166187.94
